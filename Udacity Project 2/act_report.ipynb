# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# <h1> INSIGHTS AND VISUALIZATIONS </h1>

# %% [markdown]
# 1. **The most popular source on twitter**

# %% [markdown]
# ![Screenshot%20%2857%29.png](attachment:Screenshot%20%2857%29.png)

# %% [markdown]
# People use Twitter for iPhone, the Twitter web client and tweet deck but our data analysis and visualization shows that Twitter for iPhone is far more popular, with users tweeting in excess of 1187 times per day, while the other users didn't even reach 200. Twitter web client had just 14 users and tweet deck had only 5 users.

# %% [markdown]
# 2.  **The relationship between the dog_type, favorite_count and the retweet_count**

# %% [markdown]
# ![Screenshot%20%2858%29.png](attachment:Screenshot%20%2858%29.png)

# %% [markdown]
# The doggo dog type has the highest favourite_count of about 100,000 and retweet count of about 5000 while the doggo floofer has the least.

# %% [markdown]
# 3. **The most common dog type**: The most common dog type is 'pupper' with a count of 120, followed by 'doggo' with a count of 39, followed by 'puppo' with a count of 18, followed by 'doggo, pupper' and 'floofer' with a count of 6 respectively and lastly, 'doggo, puppo' and 'doggo, floofer' with a count of 1 respectively.

# %% [markdown]
# 4. **The most common dog named**: 'Cooper' is the most popular dog name with a count of 9, followed by 'Charlie' with a count of 8, followed by 'Oliver' with a count of 7 and others.

# %% [markdown]
# 5. **The top 10 predicted P1 dog breeds**: The most predicted dog breed is 'Golden Retriever' with a count of (119) followed by 'Pembroke' with a count of (77), followed by 'Labrador_retriever' with a count of (75), followed by 'Chihuahua' with a count of (50), followed by pug with a count of (40), followed by 'Pomeranian' with a count of (28), followed by 'malamute', 'chow' and 'toy_poodle' with a count of (26) for each, and lastly 'Samoyed' with a count of (25)
